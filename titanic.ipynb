# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic_data = pd.read_csv('/content/train.csv')
# test_data = pd.read_csv('/content/test.csv')
# submission_data = pd.read_csv('/content/gender_submission.csv')

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
titanic_data.tail()
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %%
titanic_data.shape
# Out:
# (891, 12)

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.countplot(x="Survived", data=titanic_data)

# %%
sns.countplot(x="Survived", hue='Sex', data=titanic_data)

# %%
sns.countplot(x="Survived", hue='Embarked', data=titanic_data)

# %%
sns.countplot(x="Survived", hue='Pclass', data=titanic_data)

# %%
titanic_data['Age'].plot.hist(bins=8)

# %%
titanic_data['SibSp'].value_counts().plot.bar()

# %%
titanic_data['Parch'].value_counts().plot.bar()

# %%
sns.heatmap(titanic_data.isnull(), yticklabels=False, cmap='Blues')

# %%
titanic_data.drop('Cabin', axis=1, inplace=True)

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0            1         0       3  ...         A/5 21171   7.2500         S
# 1            2         1       1  ...          PC 17599  71.2833         C
# 2            3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3            4         1       1  ...            113803  53.1000         S
# 4            5         0       3  ...            373450   8.0500         S
#
# [5 rows x 11 columns]

# %%
titanic_data.drop('PassengerId', axis=1, inplace=True)
titanic_data.head()
# Out:
#    Survived  Pclass  ...     Fare Embarked
# 0         0       3  ...   7.2500        S
# 1         1       1  ...  71.2833        C
# 2         1       3  ...   7.9250        S
# 3         1       1  ...  53.1000        S
# 4         0       3  ...   8.0500        S
#
# [5 rows x 10 columns]

# %%
titanic_data.drop('Name', axis=1, inplace=True)
titanic_data.head()
# Out:
#    Survived  Pclass     Sex   Age  ...  Parch            Ticket     Fare  Embarked
# 0         0       3    male  22.0  ...      0         A/5 21171   7.2500         S
# 1         1       1  female  38.0  ...      0          PC 17599  71.2833         C
# 2         1       3  female  26.0  ...      0  STON/O2. 3101282   7.9250         S
# 3         1       1  female  35.0  ...      0            113803  53.1000         S
# 4         0       3    male  35.0  ...      0            373450   8.0500         S
#
# [5 rows x 9 columns]

# %%
titanic_data.drop('SibSp', axis=1, inplace=True)
titanic_data.head()
# Out:
#    Survived  Pclass     Sex   Age  Parch            Ticket     Fare Embarked
# 0         0       3    male  22.0      0         A/5 21171   7.2500        S
# 1         1       1  female  38.0      0          PC 17599  71.2833        C
# 2         1       3  female  26.0      0  STON/O2. 3101282   7.9250        S
# 3         1       1  female  35.0      0            113803  53.1000        S
# 4         0       3    male  35.0      0            373450   8.0500        S

# %%
titanic_data.drop('Parch', axis=1, inplace=True)
titanic_data.head()
# Out:
#    Survived  Pclass     Sex   Age            Ticket     Fare Embarked
# 0         0       3    male  22.0         A/5 21171   7.2500        S
# 1         1       1  female  38.0          PC 17599  71.2833        C
# 2         1       3  female  26.0  STON/O2. 3101282   7.9250        S
# 3         1       1  female  35.0            113803  53.1000        S
# 4         0       3    male  35.0            373450   8.0500        S

# %%
titanic_data.drop('Ticket', axis=1, inplace=True)
titanic_data.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked
# 0         0       3    male  22.0   7.2500        S
# 1         1       1  female  38.0  71.2833        C
# 2         1       3  female  26.0   7.9250        S
# 3         1       1  female  35.0  53.1000        S
# 4         0       3    male  35.0   8.0500        S

# %%
titanic_data.drop('Fare', axis=1, inplace=True)
titanic_data.head()
# Out:
#    Survived  Pclass     Sex   Age Embarked
# 0         0       3    male  22.0        S
# 1         1       1  female  38.0        C
# 2         1       3  female  26.0        S
# 3         1       1  female  35.0        S
# 4         0       3    male  35.0        S

# %%
titanic_data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# Embarked      2
# dtype: int64

# %%
titanic_data.dropna(inplace=True)

# %%
titanic_data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# Embarked    0
# dtype: int64

# %%
sns.heatmap(titanic_data.isnull(), yticklabels=False, cmap='Blues')

# %%
pclass = pd.get_dummies(titanic_data['Pclass'], drop_first=True)
pclass.head()
# Out:
#    2  3
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  0
# 4  0  1

# %%
gender = pd.get_dummies(titanic_data['Sex'], drop_first=True)
gender.head()
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
embarked = pd.get_dummies(titanic_data['Embarked'], drop_first=True)
embarked.head()
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
titanic_data = pd.concat([titanic_data, pclass, gender, embarked], axis=1)

# %%
titanic_data.head()
# Out:
#    Survived  Pclass     Sex   Age Embarked  2  3  male  Q  S
# 0         0       3    male  22.0        S  0  1     1  0  1
# 1         1       1  female  38.0        C  0  0     0  0  0
# 2         1       3  female  26.0        S  0  1     0  0  1
# 3         1       1  female  35.0        S  0  0     0  0  1
# 4         0       3    male  35.0        S  0  1     1  0  1

# %%
titanic_data.drop('Pclass', axis=1, inplace=True)
titanic_data.head()
# Out:
#    Survived     Sex   Age Embarked  2  3  male  Q  S
# 0         0    male  22.0        S  0  1     1  0  1
# 1         1  female  38.0        C  0  0     0  0  0
# 2         1  female  26.0        S  0  1     0  0  1
# 3         1  female  35.0        S  0  0     0  0  1
# 4         0    male  35.0        S  0  1     1  0  1

# %%
titanic_data.drop('Sex', axis=1, inplace=True)
titanic_data.head()
# Out:
#    Survived   Age Embarked  2  3  male  Q  S
# 0         0  22.0        S  0  1     1  0  1
# 1         1  38.0        C  0  0     0  0  0
# 2         1  26.0        S  0  1     0  0  1
# 3         1  35.0        S  0  0     0  0  1
# 4         0  35.0        S  0  1     1  0  1

# %%
titanic_data.drop('Embarked', axis=1, inplace=True)
titanic_data.head()
# Out:
#    Survived   Age  2  3  male  Q  S
# 0         0  22.0  0  1     1  0  1
# 1         1  38.0  0  0     0  0  0
# 2         1  26.0  0  1     0  0  1
# 3         1  35.0  0  0     0  0  1
# 4         0  35.0  0  1     1  0  1

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X = titanic_data.drop('Survived', axis=1)

# %%
Y = titanic_data['Survived']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=0)

# %%
log = LogisticRegression()

# %%
log.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# LogisticRegression()

# %%
p = log.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, p))
# Out:
# 0.794392523364486
